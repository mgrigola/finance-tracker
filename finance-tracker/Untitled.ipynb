# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width: 100% !important; }</style>"))
# Out:
# <style>.container { width: 100% !important; }</style>

# %%
import os
import sys
import django

module_path = os.path.abspath(os.path.join('.'))
if module_path not in sys.path:
    sys.path.append(module_path)

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "finance-site.settings")
django.setup()

# %%
from finance.models import Account, Transaction, FinanceCategory

# %%
accts=Account.objects.all()

# %%
acctSchwab=accts[0]
acctChase = accts[1]

# %%
userMe=acctChase.user

# %%
oneYearAgo=datetime.datetime.now() + datetime.timedelta(days=-365)
catSums=acctSchwab.aggregate_transactions_by_category(oneYearAgo)
# Out:
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2020-11-07 23:56:24.591412) while time zone support is active.
#   RuntimeWarning)
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2021-10-24 23:57:06.677167) while time zone support is active.
#   RuntimeWarning)

# %%
userCats = FinanceCategory.objects.filter(user=userMe)

# %%
userCats
# Out:
# <QuerySet [<FinanceCategory: FinanceCategory object (2)>, <FinanceCategory: FinanceCategory object (3)>, <FinanceCategory: FinanceCategory object (4)>, <FinanceCategory: FinanceCategory object (5)>, <FinanceCategory: FinanceCategory object (6)>, <FinanceCategory: FinanceCategory object (7)>, <FinanceCategory: FinanceCategory object (8)>, <FinanceCategory: FinanceCategory object (9)>, <FinanceCategory: FinanceCategory object (10)>, <FinanceCategory: FinanceCategory object (11)>]>

# %%
for cat in userCats:
        if not cat in catSums: catSums[cat]=0

# %%
catSums
# Out:
# {<FinanceCategory: FinanceCategory object (11)>: 0,
#  <FinanceCategory: FinanceCategory object (10)>: 0}

# %%
dateRangeStart = datetime.datetime.now() + datetime.timedelta(days=-365)
dateRangeEnd = datetime.datetime.now()

# %%
acctChase.acct_source
# Out:
# 'Chase Bank'

# %%
txs0 = acct0.transaction_set.all()

# %%
print(type(txs0))
print(len(txs0))
# Out:
# <class 'django.db.models.query.QuerySet'>
# 486

# %%
txs = acct.transaction_set.filter(tx_date__range=(dateRangeStart, dateRangeEnd))
# Out:
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2020-10-28 22:33:52.280230) while time zone support is active.
#   RuntimeWarning)
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2021-10-28 22:33:52.280230) while time zone support is active.
#   RuntimeWarning)

# %%
plotData=[(tx.tx_date, tx.balance) for tx in txs0.order_by('tx_date')]

# %%
dates = [row[0] for row in plotData]
balances = [row[1] for row in plotData]

# %%
balances
# Out:
# [19792.89,
#  19726.7,
#  19762.52,
#  19781.33,
#  19785.6,
#  19698.07,
#  19696.62,
#  19650.68,
#  19603.32,
#  19689.33,
#  19681.85,
#  19680.86,
#  19656.66,
#  19623.09,
#  19580.59,
#  19573.3,
#  19563.68,
#  19557.03,
#  19549.74,
#  19514.74,
#  19400.04,
#  19430.03,
#  19446.82,
#  19449.17,
#  19488.66,
#  19066.03,
#  19392.57,
#  18783.11,
#  18846.03,
#  18783.03,
#  18781.46,
#  18761.31,
#  18651.31,
#  18605.44,
#  18636.73,
#  18644.02,
#  18598.45,
#  18580.48,
#  18545.2,
#  18572.98,
#  18520.59,
#  21615.76,
#  21629.72,
#  20709.31,
#  21604.31,
#  20680.67,
#  20673.17,
#  20613.18,
#  20548.38,
#  20605.68,
#  20603.9,
#  20570.95,
#  20540.88,
#  20524.21,
#  20432.08,
#  20458.11,
#  20317.22,
#  20224.72,
#  20192.75,
#  20185.46,
#  20162.12,
#  20160.12,
#  20136.46,
#  20152.62,
#  20113.68,
#  20112.29,
#  20089.59,
#  19990.11,
#  19959.98,
#  19958.92,
#  19890.37,
#  19912.8,
#  19921.08,
#  19939.27,
#  22999.51,
#  22964.48,
#  22001.1,
# ...

# %%
import datetime
dateRangeStart = datetime.datetime.now() + datetime.timedelta(days=-365)
dateRangeEnd = datetime.datetime.now()
    
txs = acct0.transaction_set.filter(tx_date__range=(dateRangeStart, dateRangeEnd))
# Out:
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2020-10-28 21:38:26.980828) while time zone support is active.
#   RuntimeWarning)
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2021-10-28 21:38:26.980828) while time zone support is active.
#   RuntimeWarning)

# %%
txs
# Out:
# <QuerySet []>

# %%
acct0.load_transactions_from_file("C:/Users/m/Downloads/Chase6188_Activity_20211024.CSV")
# Out:
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2021-10-18 00:00:00) while time zone support is active.
#   RuntimeWarning)
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2021-10-15 00:00:00) while time zone support is active.
#   RuntimeWarning)
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2021-10-14 00:00:00) while time zone support is active.
#   RuntimeWarning)
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2021-10-13 00:00:00) while time zone support is active.
#   RuntimeWarning)
# ...

# %%
account_list = Account.objects.filter(user_id=userMe)
dateRangeStart = datetime.datetime.now() + datetime.timedelta(days=-365)
dateRangeEnd = datetime.datetime.now()
acct0 = account_list[0]
txs0 = acct0.transaction_set.filter(tx_date__range=(dateRangeStart, dateRangeEnd))
# Out:
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2020-10-28 22:38:20.052910) while time zone support is active.
#   RuntimeWarning)
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2021-10-28 22:38:20.052910) while time zone support is active.
#   RuntimeWarning)

# %%
txs0.count()
# Out:
# 0

# %%
acctSchwab.transaction_set.order_by('-tx_date')[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-95-fe1a9952185f> in <module>()
# ----> 1 acctSchwab.transaction_set.order_by('-tx_date')[0]
#
# c:\python36\lib\site-packages\django\db\models\query.py in __getitem__(self, k)
#     301         qs.query.set_limits(k, k + 1)
#     302         qs._fetch_all()
# --> 303         return qs._result_cache[0]
#     304
#     305     def __and__(self, other):
#
# IndexError: list index out of range

# %%
try:
    x = acctSchwab.transaction_set.order_by('-tx_date')[0]
except:
    x = datetime.datetime.min()
finally:
    print(x)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-98-66c657a10fd0> in <module>()
#       1 try:
# ----> 2     x = acctSchwab.transaction_set.order_by('-tx_date')[0]
#       3 except:
#
# c:\python36\lib\site-packages\django\db\models\query.py in __getitem__(self, k)
#     302         qs._fetch_all()
# --> 303         return qs._result_cache[0]
#     304
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-66c657a10fd0> in <module>()
#       3 except:
# ----> 4     x = datetime.datetime.min()
#       5 finally:
#
# TypeError: 'datetime.datetime' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2021, 10, 31, 17, 31, 14, 155402)

# %%
acctChase.acct_source
# Out:
# 'Chase Bank'

# %%
acctType = 'chase'

if acctType == 'chase':
    tsvHeaders = {'Details', 'Posting Date','Description','Amount','Type','Balance','Check or Slip #'}
elif acctType == 'schwab':
    tsvHeaders = {'Details', 'Posting Date','Description','Amount','Type','Balance','Check or Slip #'}
else:
    tsvHeaders = {'Description', 'Date','Type','Amount','Balance'}

# %%
acctType = 'chase'

tsvHeaders = if acctType == 'chase':
    {'Details', 'Posting Date','Description','Amount','Type','Balance','Check or Slip #'}
elif acctType == 'schwab':
    {'Details', 'Posting Date','Description','Amount','Type','Balance','Check or Slip #'}
else:
    {'Description', 'Date','Type','Amount','Balance'}
# Out:
#   File "<ipython-input-110-b57b08fe52a7>", line 3
#     tsvHeaders = if acctType == 'chase':
#                   ^
# SyntaxError: invalid syntax

# %%
acctSchwab.acct_source
# Out:
# 'Schwab'

# %%
acctChase.acct_source
# Out:
# 'Chase Bank'

# %%
txs = acctChase.transaction_set.filter(tx_date__range=(dateRangeStart, dateRangeEnd))
# Out:
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2020-10-28 22:38:20.052910) while time zone support is active.
#   RuntimeWarning)
# c:\python36\lib\site-packages\django\db\models\fields\__init__.py:1421: RuntimeWarning: DateTimeField Transaction.tx_date received a naive datetime (2021-10-28 22:38:20.052910) while time zone support is active.
#   RuntimeWarning)

# %%
plotData = [(tx.tx_date, tx.balance) for tx in txs.order_by('tx_date')]

# %%
len(plotData)
# Out:
# 286

# %%
plotData.pop()
# Out:
# (datetime.datetime(2021, 10, 18, 0, 0, tzinfo=<UTC>), 27863.94)

# %%
plotData = [(tx.tx_date, tx.balance) for tx in txs.order_by('tx_date', 'id')]

# %%
plotData = [(tx.tx_date, tx.balance, tx.amount) for tx in txs.order_by('tx_date', '-id')]

# %%
debitSum = 0;
[debitSum if row[2]>0 else debitSum+=row[2] for row in plotData ]
# Out:
# [-16.4,
#  0,
#  -48.01,
#  -770.0,
#  -203.39,
#  -18.33,
#  0,
#  -102.57,
#  -9.99,
#  -0.99,
#  -1.29,
#  -38.99,
#  -10.0,
#  -17.34,
#  -99.99,
#  -50.0,
#  -74.31,
#  -11.63,
#  0,
#  -56.36,
#  -507.5,
#  0,
#  -64.78,
#  -18.55,
#  -94.16,
#  -285.81,
#  -9.53,
#  -30.98,
#  -27.19,
#  -84.61,
#  -18.04,
#  -20.66,
#  -16.96,
#  -31.86,
#  -40.33,
#  -53.09,
#  -198.87,
#  -22.17,
#  -5.57,
#  -25.0,
#  -21.24,
#  -26.0,
#  0,
#  -16.26,
#  -69.94,
#  -38.99,
#  -30.0,
#  -30.0,
#  -9.99,
#  -186.87,
#  -47.98,
#  -10.0,
#  -219.93,
#  -162.7,
#  -162.72,
#  -125.0,
#  -95.85,
#  -79.71,
#  -70.5,
#  0,
#  -161.62,
#  -119.61,
#  -99.99,
#  -232.69,
#  -17.19,
#  -9.22,
#  -11.66,
#  -10.84,
#  -102.42,
#  -109.92,
#  -6000.0,
#  -4000.0,
#  -2.11,
#  -18.68,
#  -17.31,
#  -22.19,
#  -165.81,
#  -28.11,
#  -15.57,
#  0,
#  -17.77,
#  -41.57,
#  -30.0,
#  -219.99,
#  -98.99,
#  -43.28,
#  -34.75,
#  -40.0,
#  -38.99,
#  -9.99,
#  -50.33,
#  -10.0,
#  -26.0,
#  0,
#  -66.22,
# ...

# %%
plotData[0]
# Out:
# (datetime.datetime(2020, 10, 29, 0, 0, tzinfo=<UTC>), 8028.85, -16.4)

# %%
plotData[286]
# Out:
# (datetime.datetime(2021, 10, 18, 0, 0, tzinfo=<UTC>), 27853.94, -10.0)

# %%
map(lambda x: debitSum if x[2]>0 else debitSum+=x[2], plotData)
# Out:
#   File "<ipython-input-135-ad18ff699c0f>", line 1
#     map(lambda x: debitSum if x[2]>0 else debitSum+=x[2], plotData)
#                                                    ^
# SyntaxError: invalid syntax

# %%
debitDates = [x[0] for x in filter(lambda x: x[2] < 0, plotData)]

# %%
debitData = [q for q in filter(lambda x: x[2] < 0, plotData)]
debitDates = [x[0] for x in debitData]
debitVals = [-x[2] for x in debitData]
debitVals = list(itertools.accumulate(debitVals, operator.add))

# %%
list(itertools.accumulate(list(zip(*debitData))[2], operator.add))
# Out:
# [-16.4,
#  -64.41,
#  -834.41,
#  -1037.8,
#  -1056.1299999999999,
#  -1158.6999999999998,
#  -1168.6899999999998,
#  -1169.6799999999998,
#  -1170.9699999999998,
#  -1209.9599999999998,
#  -1219.9599999999998,
#  -1237.2999999999997,
#  -1337.2899999999997,
#  -1387.2899999999997,
#  -1461.5999999999997,
#  -1473.2299999999998,
#  -1529.5899999999997,
#  -2037.0899999999997,
#  -2101.87,
#  -2120.42,
#  -2214.58,
#  -2500.39,
#  -2509.92,
#  -2540.9,
#  -2568.09,
#  -2652.7000000000003,
#  -2670.7400000000002,
#  -2691.4,
#  -2708.36,
#  -2740.2200000000003,
#  -2780.55,
#  -2833.6400000000003,
#  -3032.51,
#  -3054.6800000000003,
#  -3060.2500000000005,
#  -3085.2500000000005,
#  -3106.4900000000002,
#  -3132.4900000000002,
#  -3148.7500000000005,
#  -3218.6900000000005,
#  -3257.6800000000003,
#  -3287.6800000000003,
#  -3317.6800000000003,
#  -3327.67,
#  -3514.54,
#  -3562.52,
#  -3572.52,
#  -3792.45,
#  -3955.1499999999996,
#  -4117.87,
#  -4242.87,
#  -4338.72,
#  -4418.43,
# ...

# %%
import itertools, operator

# %%
[q[2] for q in itertools.accumulate(filter(lambda x: x[2] < 0, plotData), operator.add)]
# Out:
# [-16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
#  -16.4,
# ...

# %%
txData = [(tx.tx_date, tx.balance, tx.amount) for tx in txs.order_by('tx_date', '-id')]
creditDates = [x[0] for x in filter(lambda x: x[2] > 0, txData)]
creditVals = [x[2] for x in filter(lambda x: x[2] > 0, txData)]
creditVals = list(itertools.accumulate(creditVals, operator.add))

# %%
creditVals
# Out:
# [2020.6,
#  3998.45,
#  4236.599999999999,
#  6214.449999999999,
#  8192.31,
#  10170.16,
#  12150.31,
#  14130.46,
#  15990.91,
#  17851.36,
#  19711.81,
#  21572.260000000002,
#  23432.710000000003,
#  25293.160000000003,
#  27196.920000000002,
#  29057.36,
#  29567.74,
#  31428.190000000002,
#  32080.870000000003,
#  33941.32,
#  35801.77,
#  37662.219999999994,
#  39522.66999999999,
#  41383.11999999999,
#  43243.569999999985,
#  45104.01999999998,
#  46964.46999999998,
#  48824.91999999998,
#  50685.36999999997]

# %%
acctChase.id
